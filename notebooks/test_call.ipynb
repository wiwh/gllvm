# %%
from typing import Any


class Edvin:
    def __init__(self):
        self.name = "Edvin"
    def __call__(self, *args: Any, **kwds: Any) -> Any:
        self.forward()
    
    def forward(self):
        print("I'm called")


Ed = Edvin()

Ed()
# Out:
# I'm called
